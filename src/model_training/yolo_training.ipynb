# %%
import os
os.chdir("/content/drive/MyDrive/YOLO_training")

# %%
ls
# Out:
# yolo_training.ipynb  yolov5/

# %%
# !git clone https://github.com/ultralytics/yolov5.git
# Out:
# fatal: destination path 'yolov5' already exists and is not an empty directory.

# %%
# we need to upload images and yaml file in the previous images

# %%
os.chdir("yolov5")

# %%
# !ls
# Out:
# benchmarks.py	 data_images  LICENSE	       requirements.txt  tutorial.ipynb
# CITATION.cff	 data.yaml    models	       runs		 utils
# classify	 detect.py    __pycache__      segment		 val.py
# CONTRIBUTING.md  export.py    README.md        setup.cfg	 yolov5s.pt
# data		 hubconf.py   README.zh-CN.md  train.py

# %% [markdown]
# Install all required packages from requirements.txt

# %%
# !pip install -r requirements.txt
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %% [markdown]
# **Training yolo v5 model**

# %%
# !python train.py --data data.yaml --weights yolov5s.pt --img 640 --batch-size 8 --name Model --epochs 50  # from pretrained (recommended)
# Out:
# train: weights=yolov5s.pt, cfg=, data=data.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=50, batch_size=8, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=Model, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: ⚠️ YOLOv5 is out of date by 1 commit. Use 'git pull' or 'git clone https://github.com/ultralytics/yolov5' to update.
# YOLOv5 🚀 v7.0-132-ga82132c Python-3.9.16 torch-1.13.1+cu116 CUDA:0 (Tesla T4, 15102MiB)
#
# ...

# %%
# Resuming the model training
#!!python train.py --data data.yaml --weights runs/train/Model2/weights/best.pt --img 640 --batch-size 8 --name Model --epochs 50

# %% [markdown]
# We cannot use pytorch model directly in open cv, we need to export this model to save in opencv

# %%
# Export the model in ONNX file

#!python export.py --weights runs/train/Model2/weights/best.pt --include onnx --throwing error
# !python export.py --weights runs/train/Model2/weights/best.pt --include onnx --simplify --opset 12
# Out:
# export: data=data/coco128.yaml, weights=['runs/train/Model2/weights/best.pt'], imgsz=[640, 640], batch_size=1, device=cpu, half=False, inplace=False, keras=False, optimize=False, int8=False, dynamic=False, simplify=True, opset=12, verbose=False, workspace=4, nms=False, agnostic_nms=False, topk_per_class=100, topk_all=100, iou_thres=0.45, conf_thres=0.25, include=['onnx']
# YOLOv5 🚀 v7.0-132-ga82132c Python-3.9.16 torch-1.13.1+cu116 CPU
#
# Fusing layers...
# Model summary: 157 layers, 7064065 parameters, 0 gradients, 15.9 GFLOPs
#
# PyTorch: starting from runs/train/Model2/weights/best.pt with output shape (1, 25200, 25) (13.8 MB)
# requirements: YOLOv5 requirement "onnx>=1.12.0" not found, attempting AutoUpdate...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.5/13.5 MB 93.1 MB/s eta 0:00:00
# ...
#
# requirements: 1 package updated per ['onnx>=1.12.0']
# ...
